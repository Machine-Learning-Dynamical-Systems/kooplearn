# %%
import numpy as np
import torch
cuda = torch.device('cuda')
import matplotlib.pyplot as plt
from tqdm import tqdm
import h5py
from kernels import gaussian, matern
from pykeops.torch import LazyTensor
from _kernel_helpers import pdist_sym, pdist
#Paranoia
from IPython.display import set_matplotlib_formats
set_matplotlib_formats('svg')
__useTeX__ = True
if __useTeX__:
    plt.rcParams.update({
        "text.usetex": False,
        "mathtext.fontset": "cm",
        "font.family": "serif",
        "font.serif": ["Computer Modern Roman"]
    })

# %% [markdown]
# ### Load data

# %%
def print_attrs(name, obj):
    print(name)
    for key, val in obj.attrs.items():
        print (f"    {key}: {val}")
chignolin_path = '../data/md_datasets/chignolin-unbiased/CLN025-0-protein-ALL.h5'
f = h5py.File(chignolin_path, 'r')
for key, val in f.attrs.items():
    print (f"{key}: {val}")
f.visititems(print_attrs)
# Out:
# CLASS: b'GROUP'
# FILTERS: 65793
# PYTABLES_FORMAT_VERSION: b'2.1'
# TITLE: Empty(dtype=dtype('S1'))
# VERSION: b'1.0'
# application: b'MDTraj'
# conventionVersion: b'1.1'
# conventions: b'Pande'
# program: b'MDTraj'
# programVersion: b'1.9.5'
# title: b'title'
# cell_angles
#     CLASS: b'EARRAY'
#     EXTDIM: 0
#     TITLE: Empty(dtype=dtype('S1'))
#     VERSION: b'1.1'
#     units: b'degrees'
# cell_lengths
#     CLASS: b'EARRAY'
#     EXTDIM: 0
#     TITLE: Empty(dtype=dtype('S1'))
#     VERSION: b'1.1'
#     units: b'nanometers'
# coordinates
#     CLASS: b'EARRAY'
#     EXTDIM: 0
#     TITLE: Empty(dtype=dtype('S1'))
#     VERSION: b'1.1'
#     units: b'nanometers'
# topology
#     CLASS: b'ARRAY'
#     FLAVOR: b'python'
#     TITLE: Empty(dtype=dtype('S1'))
#     VERSION: b'2.4'

# %%
top_data = eval(f['topology'][0])['chains'][0]['residues']
heavy_atoms = []
for res in top_data:
    for atom in res['atoms']:
        if atom['element'] != 'H':
            heavy_atoms.append(atom['index'])
import itertools
pairs = []
for result in itertools.combinations(heavy_atoms, 2):
    pairs.append(result)
pairs = np.array(pairs)

# %%
pairs.shape
# Out:
# (4278, 2)

# %%
import mdtraj as md
traj = md.load_hdf5(chignolin_path)
distances = md.compute_distances(traj, pairs)

# %%
num_steps = 7000
n_frames = len(traj)
stride = int(n_frames/num_steps)
centers = distances[100000::stride,:]

# %%
centers.shape
# Out:
# (5740, 4278)

# %%
D = pdist_sym(centers, distances.dtype)
#Could be chosen more accurately
l = np.std(D)
print(l)
# Out:
# 594.7074

# %%
K_all = matern(D, l=np.sqrt(l))

# %%
plt.matshow(K_all)
plt.colorbar()
# Out:
# findfont: Font family ['serif'] not found. Falling back to DejaVu Sans.

# %%
n = K_all.shape[0] - 1
K = K_all[:-1, :-1]
K_T = K_all[-1,:-1]
reg = 0
alpha = np.linalg.solve(K + reg*np.eye(n), K_T)
plt.plot(alpha)
S = np.zeros((n,n))
S[1:,:-1] = np.eye(n-1)
S[:,-1] = alpha

# %%
vals, R_vecs = np.linalg.eig(S)
logvals = np.log(vals)

# %%
L_vecs = np.vander(vals, increasing=True)
Id = L_vecs@R_vecs
zero_mat = Id - np.diag(np.diag(Id))
np.abs(zero_mat).max()
# Out:
# 4.455429168753219e-09

# %%
mask = (np.imag(vals) > 1e-8)
figure, axes = plt.subplots()
#draw_circle = plt.Circle((0, 0), 1,fill=False, lw =0.5)
axes.set_aspect(1)
#axes.add_artist(draw_circle)
axes.plot(np.real(vals), np.imag(vals), 'k.')
axes.plot(np.real(vals[mask]), np.imag(vals[mask]), 'b.')
axes.set_xlabel(r'$\rm{Re}\, \lambda$')
axes.set_ylabel(r'$\rm{Im}\, \lambda$')
# Out:
# Text(0, 0.5, '$\\rm{Im}\\, \\lambda$')
# findfont: Font family ['serif'] not found. Falling back to DejaVu Sans.

# %%
sort_perm = np.argsort(np.abs(vals[mask]))
D_test = pdist(distances[::50], centers[:-1,:], distances.dtype)

# %%
CVs = (matern(D_test, l=np.sqrt(l))@R_vecs[:, mask][:, sort_perm])*vals[mask][sort_perm]
from sklearn.decomposition import PCA
pca = PCA(n_components=5)
reduced_CVs = pca.fit_transform(np.real(CVs))

# %%
print(pca.explained_variance_ratio_)
# Out:
# [0.90679668 0.055445   0.01060623 0.00627054 0.00459127]

# %%
import ipywidgets as widgets

# %%
def f(x):
    plt.hist(reduced_CVs[:,x], 100)
widgets.interact(f, x=widgets.IntSlider(min=0, max=reduced_CVs.shape[1] - 1, step=1, value=0));
# Out:
# interactive(children=(IntSlider(value=0, description='x', max=4), Output()), _dom_classes=('widget-interact',)…

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from stateinterpreter import Classifier, identify_metastable_states, load_dataframe, descriptors_from_traj, sample
from stateinterpreter.plot import plot_states, plot_combination_states_features
from stateinterpreter.visualize import visualize_features

# %%
chignolin_data_path = '../data/md_datasets/chignolin-unbiased/'
traj_dict = {
        'trajectory' : chignolin_data_path+'CLN025-0-protein-ALL.dcd',
        'topology' : chignolin_data_path+'CLN025-0-protein.pdb'
    }
stride = 50
#Compute descriptors
descriptors, feats_info = descriptors_from_traj(traj_dict, descriptors=['hbonds_contacts'], stride=stride)
# Out:
# Computing Hydrogen bonds contacts
# Donors: [0, 15, 23, 36, 44, 70, 85, 91, 99, 106, 112, 120, 130, 147, 160]
# Acceptors: [  0  15  22  23  36  43  44  52  53  55  56  69  70  81  82  84  85  91
#   98  99 105 106 112 119 120 130 143 145 146 147 160]
# Descriptors: (10495, 318)

# %%
import pandas as pd
col_names = [f"Kernel_DMD_{idx}" for idx in range(reduced_CVs.shape[1])]
CVs = pd.DataFrame(reduced_CVs, columns=col_names)

# %%
cv_list = ["Kernel_DMD_0"]
kBT = 2.8
states_labels = identify_metastable_states(CVs, cv_list, kBT, fes_cutoff=0.1, bw_method=0.25, optimizer_kwargs={'num_init' : 50})
# Out:
# DEV >>> Finding Local Minima
# DEV >>> Basin Assignment
# Found 2 local minima with selected populations:
# 	Basin 0 -> 3658 configurations.
# 	Basin 1 -> 419 configurations.

# %%
sample_obj, features_names, classes_names = sample(descriptors, states_labels, 300)
regularizers = np.geomspace(0.01, 1, 25)
classifier = Classifier(sample_obj, features_names, classes_names)
classifier.compute(regularizers, max_iter= 10000, quadratic_kernel=False)

classifier.plot();
# Out:
# Optimizing Lasso Estimator: 100%|██████████| 25/25 [00:00<00:00, 238.43it/s]

# %%
reg = 10**(-0.4)
classifier.print_selected(reg)
# Out:
# Accuracy: 100%
# State 0:
# [100.0%]  HB_CONTACT ASP3-O -- GLY7-N
# State 1:
# [100.0%]  HB_CONTACT ASP3-O -- GLY7-N

# %%
classifier.classes
# Out:
# {0: 0, 1: 1}

# %%
visualize_features(traj, states_labels, classifier.classes, classifier._get_selected(reg), feats_info)
# Out:
# NGLWidget(max_frame=1)
